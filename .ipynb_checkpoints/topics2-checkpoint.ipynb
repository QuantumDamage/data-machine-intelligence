# %%
import requests
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
r = requests.get('https://api.stackexchange.com/2.2/tags?order=desc&sort=popular&site=datascience')
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'application/json; charset=utf-8'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text
# Out:
# '{"items":[{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":2806,"name":"machine-learning"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":1234,"name":"python"},{"has_synonyms":true,"is_moderator_only":false,"is_required":false,"count":1131,"name":"neural-network"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":864,"name":"deep-learning"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":850,"name":"classification"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":706,"name":"r"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":611,"name":"data-mining"},{"has_synonyms":true,"is_moderator_only":false,"is_required":false,"count":495,"name":"scikit-learn"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":475,"name":"nlp"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":435,"name":"clustering"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":428,"name":"predictive-modeling"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":404,"name":"dataset"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":359,"name":"keras"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":347,"name":"time-series"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":338,"name":"tensorflow"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":329,"name":"regression"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":309,"name":"text-mining"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":301,"name":"statistics"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":284,"name":"bigdata"},{"has_synonyms":true,"is_moderator_only":false,"is_required":false,"count":234,"name":"visualization"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":233,"name":"feature-selection"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":212,"name":"random-forest"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":212,"name":"convnet"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":207,"name":"pandas"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":207,"name":"algorithms"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":193,"name":"svm"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":191,"name":"data-cleaning"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":183,"name":"logistic-regression"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":178,"name":"decision-trees"},{"has_synonyms":false,"is_moderator_only":false,"is_required":false,"count":176,"name":"data"}],"has_more":true,"quota_max":300,"quota_remaining":258}'

# %%
ds_df = pd.DataFrame(r.json()["items"])

# %%
ds_df
# Out:
#     count  has_synonyms  is_moderator_only  is_required                 name
# 0    2806         False              False        False     machine-learning
# 1    1234         False              False        False               python
# 2    1131          True              False        False       neural-network
# 3     864         False              False        False        deep-learning
# 4     850         False              False        False       classification
# 5     706         False              False        False                    r
# 6     611         False              False        False          data-mining
# 7     495          True              False        False         scikit-learn
# 8     475         False              False        False                  nlp
# 9     435         False              False        False           clustering
# 10    428         False              False        False  predictive-modeling
# 11    404         False              False        False              dataset
# 12    359         False              False        False                keras
# 13    347         False              False        False          time-series
# 14    338         False              False        False           tensorflow
# 15    329         False              False        False           regression
# 16    309         False              False        False          text-mining
# 17    301         False              False        False           statistics
# 18    284         False              False        False              bigdata
# 19    234          True              False        False        visualization
# 20    233         False              False        False    feature-selection
# 21    212         False              False        False        random-forest
# 22    212         False              False        False              convnet
# 23    207         False              False        False               pandas
# 24    207         False              False        False           algorithms
# 25    193         False              False        False                  svm
# 26    191         False              False        False        data-cleaning
# 27    183         False              False        False  logistic-regression
# 28    178         False              False        False       decision-trees
# 29    176         False              False        False                 data

# %%
pairs = []
for index, row in ds_df.iterrows():
    print(row["name"],index)
    r = requests.get('https://api.stackexchange.com/2.2/tags/' + row["name"] + '/related?site=datascience')
    r.status_code
    relatedtags_df = pd.DataFrame(r.json()["items"])
    top_rt_df = relatedtags_df.head(n=5).tail(n=4)
    for index2, row2, in top_rt_df.iterrows():
        pairs.append(tuple(sorted([row["name"],row2["name"]])))
    if (index == 3):
        break
# Out:
# machine-learning 0
# python 1
# neural-network 2
# deep-learning 3

# %%
pairs
# Out:
# [('machine-learning', 'neural-network'),
#  ('classification', 'machine-learning'),
#  ('deep-learning', 'machine-learning'),
#  ('machine-learning', 'python'),
#  ('machine-learning', 'python'),
#  ('python', 'scikit-learn'),
#  ('pandas', 'python'),
#  ('neural-network', 'python'),
#  ('machine-learning', 'neural-network'),
#  ('deep-learning', 'neural-network'),
#  ('keras', 'neural-network'),
#  ('neural-network', 'python'),
#  ('deep-learning', 'machine-learning'),
#  ('deep-learning', 'neural-network'),
#  ('deep-learning', 'keras'),
#  ('deep-learning', 'tensorflow')]

# %% [raw]
# from collections import Counter
# res = dict(Counter(pairs))
# res_DF = pd.DataFrame(res, index=None)

# %%
res
# Out:
# {('classification', 'machine-learning'): 1,
#  ('deep-learning', 'keras'): 1,
#  ('deep-learning', 'machine-learning'): 2,
#  ('deep-learning', 'neural-network'): 2,
#  ('deep-learning', 'tensorflow'): 1,
#  ('keras', 'neural-network'): 1,
#  ('machine-learning', 'neural-network'): 2,
#  ('machine-learning', 'python'): 2,
#  ('neural-network', 'python'): 2,
#  ('pandas', 'python'): 1,
#  ('python', 'scikit-learn'): 1}

# %%
import networkx as nx

# %%
# %matplotlib inline

# %%
G = nx.Graph()
G.add_edges_from(pairs)
plt.figure(3,figsize=(15,15)) 
nx.draw(G,with_labels=True)
plt.show()

# %%
G.number_of_nodes()
# Out:
# 35

# %%
import operator

# %%
sorted_x = sorted(dict(nx.degree(G)).items(), key=operator.itemgetter(1))

# %%
sorted_x
# Out:
# [('k-means', 1),
#  ('feature-engineering', 1),
#  ('apache-hadoop', 1),
#  ('feature-extraction', 1),
#  ('dataframe', 1),
#  ('pandas', 4),
#  ('tensorflow', 4),
#  ('algorithms', 4),
#  ('decision-trees', 4),
#  ('nlp', 4),
#  ('feature-selection', 4),
#  ('regression', 4),
#  ('statistics', 4),
#  ('bigdata', 4),
#  ('logistic-regression', 4),
#  ('text-mining', 4),
#  ('data', 4),
#  ('data-cleaning', 4),
#  ('convnet', 4),
#  ('visualization', 4),
#  ('svm', 4),
#  ('time-series', 4),
#  ('clustering', 5),
#  ('predictive-modeling', 5),
#  ('keras', 5),
#  ('dataset', 5),
#  ('random-forest', 5),
#  ('deep-learning', 6),
#  ('scikit-learn', 7),
#  ('neural-network', 8),
#  ('r', 9),
#  ('classification', 11),
#  ('data-mining', 13),
#  ('python', 19),
#  ('machine-learning', 29)]
